# %%
# %matplotlib inline
import sys
#sys.path.insert(1, 'Users/Flavia/')

# %%
import math
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
#import missingno as msno

from collections import defaultdict
from scipy.stats.stats import pearsonr

# %%
import cleaning as cl
# %load_ext autoreload
# %autoreload 2

# %%
df = pd.read_csv('/Users/Flavia/GiuliaVolpi93-dm_carvana-aa978dc39f6b/data/training.csv')

# %%
cl.cleaning(df)

# %%
X = df[["VehBCost", "WarrantyCost", "MMRAcquisitionAuctionAveragePrice"]]

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)
X[:5]
# Out:
# array([[-0.37422991, -1.41467453,  0.28838605],
#        [-1.63221553,  0.80378455, -0.32690017],
#        [ 0.46442718, -1.09110712,  0.88263285],
#        [-1.19791097,  0.80985144, -0.636881  ],
#        [-0.63181744,  0.78962847, -0.35027731]])

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
kmeans = KMeans(n_clusters=4, n_init=10, max_iter=100)
kmeans.fit(X)
np.unique(kmeans.labels_, return_counts=True)
centers = scaler.inverse_transform(kmeans.cluster_centers_)

plt.scatter(df['VehBCost'], df['WarrantyCost'], 
            c=kmeans.labels_, s=20)
plt.scatter(centers[:, 0], centers[:, 1], s=200, marker='*', c='r')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.ylabel('VehBCost', fontsize=22)
plt.xlabel('WarrantyCost', fontsize=22)
plt.show()
plt.scatter(df['VehBCost'], df['MMRAcquisitionAuctionAveragePrice'], 
            c=kmeans.labels_, s=20)
plt.scatter(centers[:, 0], centers[:, 2], s=200, marker='*', c='r')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.ylabel('VehBCost', fontsize=22)
plt.xlabel('MMRAcquisitionAuctionAveragePrice', fontsize=22)
plt.show()
plt.scatter(df['MMRAcquisitionAuctionAveragePrice'], df['WarrantyCost'], 
            c=kmeans.labels_, s=20)
plt.scatter(centers[:, 2], centers[:, 1], s=200, marker='*', c='r')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.ylabel('MMRAcquisitionAuctionAveragePrice', fontsize=22)
plt.xlabel('WarrantyCost', fontsize=22)
plt.show()

plt.figure(figsize=(12, 4))
for i in range(0, len(centers)):
    plt.plot(centers[i], marker='o', label='Cluster %s' % i)
plt.tick_params(axis='both', which='major', labelsize=22)
plt.xticks(np.arange(3), ("VehBCost", "WarrantyCost", "MMRAcquisitionAuctionAveragePrice"), fontsize=16)
plt.legend(fontsize=20)
plt.show()

print('SSE %s' % kmeans.inertia_)
print('Silhouette %s' % silhouette_score(X, kmeans.labels_))
# Out:
# SSE 55838.83789922105
# Silhouette 0.31557308710569876

# %%
kmeans = KMeans(n_clusters=5, n_init=10, max_iter=100)
kmeans.fit(X)
np.unique(kmeans.labels_, return_counts=True)
centers = scaler.inverse_transform(kmeans.cluster_centers_)

plt.scatter(df['VehBCost'], df['WarrantyCost'], 
            c=kmeans.labels_, s=20)
plt.scatter(centers[:, 0], centers[:, 1], s=200, marker='*', c='r')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.ylabel('VehBCost', fontsize=22)
plt.xlabel('WarrantyCost', fontsize=22)
plt.show()
plt.scatter(df['VehBCost'], df['MMRAcquisitionAuctionAveragePrice'], 
            c=kmeans.labels_, s=20)
plt.scatter(centers[:, 0], centers[:, 2], s=200, marker='*', c='r')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.ylabel('VehBCost', fontsize=22)
plt.xlabel('MMRAcquisitionAuctionAveragePrice', fontsize=22)
plt.show()
plt.scatter(df['MMRAcquisitionAuctionAveragePrice'], df['WarrantyCost'], 
            c=kmeans.labels_, s=20)
plt.scatter(centers[:, 2], centers[:, 1], s=200, marker='*', c='r')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.ylabel('MMRAcquisitionAuctionAveragePrice', fontsize=22)
plt.xlabel('WarrantyCost', fontsize=22)
plt.show()

plt.figure(figsize=(12, 4))
for i in range(0, len(centers)):
    plt.plot(centers[i], marker='o', label='Cluster %s' % i)
plt.tick_params(axis='both', which='major', labelsize=22)
plt.xticks(np.arange(3), ("VehBCost", "WarrantyCost", "MMRAcquisitionAuctionAveragePrice"), fontsize=16)
plt.legend(fontsize=20)
plt.show()

print('SSE %s' % kmeans.inertia_)
print('Silhouette %s' % silhouette_score(X, kmeans.labels_))
# Out:
# SSE 44920.87874713621
# Silhouette 0.31428114835625415

# %%
kmeans = KMeans(n_clusters=6, n_init=10, max_iter=100)
kmeans.fit(X)
np.unique(kmeans.labels_, return_counts=True)
centers = scaler.inverse_transform(kmeans.cluster_centers_)

plt.scatter(df['VehBCost'], df['WarrantyCost'], 
            c=kmeans.labels_, s=20)
plt.scatter(centers[:, 0], centers[:, 1], s=200, marker='*', c='r')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.ylabel('VehBCost', fontsize=22)
plt.xlabel('WarrantyCost', fontsize=22)
plt.show()
plt.scatter(df['VehBCost'], df['MMRAcquisitionAuctionAveragePrice'], 
            c=kmeans.labels_, s=20)
plt.scatter(centers[:, 0], centers[:, 2], s=200, marker='*', c='r')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.ylabel('VehBCost', fontsize=22)
plt.xlabel('MMRAcquisitionAuctionAveragePrice', fontsize=22)
plt.show()
plt.scatter(df['MMRAcquisitionAuctionAveragePrice'], df['WarrantyCost'], 
            c=kmeans.labels_, s=20)
plt.scatter(centers[:, 2], centers[:, 1], s=200, marker='*', c='r')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.ylabel('MMRAcquisitionAuctionAveragePrice', fontsize=22)
plt.xlabel('WarrantyCost', fontsize=22)
plt.show()

plt.figure(figsize=(12, 4))
for i in range(0, len(centers)):
    plt.plot(centers[i], marker='o', label='Cluster %s' % i)
plt.tick_params(axis='both', which='major', labelsize=22)
plt.xticks(np.arange(3), ("VehBCost", "WarrantyCost", "MMRAcquisitionAuctionAveragePrice"), fontsize=16)
plt.legend(fontsize=20)
plt.show()

print('SSE %s' % kmeans.inertia_)
print('Silhouette %s' % silhouette_score(X, kmeans.labels_))
# Out:
# SSE 40085.39386100316
# Silhouette 0.28795946639723347

# %%
kmeans = KMeans(n_clusters=7, n_init=10, max_iter=100)
kmeans.fit(X)
np.unique(kmeans.labels_, return_counts=True)
centers = scaler.inverse_transform(kmeans.cluster_centers_)

plt.scatter(df['VehBCost'], df['WarrantyCost'], 
            c=kmeans.labels_, s=20)
plt.scatter(centers[:, 0], centers[:, 1], s=200, marker='*', c='r')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.ylabel('VehBCost', fontsize=22)
plt.xlabel('WarrantyCost', fontsize=22)
plt.show()
plt.scatter(df['VehBCost'], df['MMRAcquisitionAuctionAveragePrice'], 
            c=kmeans.labels_, s=20)
plt.scatter(centers[:, 0], centers[:, 2], s=200, marker='*', c='r')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.ylabel('VehBCost', fontsize=22)
plt.xlabel('MMRAcquisitionAuctionAveragePrice', fontsize=22)
plt.show()
plt.scatter(df['MMRAcquisitionAuctionAveragePrice'], df['WarrantyCost'], 
            c=kmeans.labels_, s=20)
plt.scatter(centers[:, 2], centers[:, 1], s=200, marker='*', c='r')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.ylabel('MMRAcquisitionAuctionAveragePrice', fontsize=22)
plt.xlabel('WarrantyCost', fontsize=22)
plt.show()

plt.figure(figsize=(12, 4))
for i in range(0, len(centers)):
    plt.plot(centers[i], marker='o', label='Cluster %s' % i)
plt.tick_params(axis='both', which='major', labelsize=22)
plt.xticks(np.arange(3), ("VehBCost", "WarrantyCost", "MMRAcquisitionAuctionAveragePrice"), fontsize=16)
plt.legend(fontsize=20)
plt.show()

print('SSE %s' % kmeans.inertia_)
print('Silhouette %s' % silhouette_score(X, kmeans.labels_))
# Out:
# SSE 35790.56022919082
# Silhouette 0.2959006022175787

# %%
kmeans = KMeans(n_clusters=8, n_init=10, max_iter=100)
kmeans.fit(X)
np.unique(kmeans.labels_, return_counts=True)
centers = scaler.inverse_transform(kmeans.cluster_centers_)

plt.scatter(df['VehBCost'], df['WarrantyCost'], 
            c=kmeans.labels_, s=20)
plt.scatter(centers[:, 0], centers[:, 1], s=200, marker='*', c='r')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.ylabel('VehBCost', fontsize=22)
plt.xlabel('WarrantyCost', fontsize=22)
plt.show()
plt.scatter(df['VehBCost'], df['MMRAcquisitionAuctionAveragePrice'], 
            c=kmeans.labels_, s=20)
plt.scatter(centers[:, 0], centers[:, 2], s=200, marker='*', c='r')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.ylabel('VehBCost', fontsize=22)
plt.xlabel('MMRAcquisitionAuctionAveragePrice', fontsize=22)
plt.show()
plt.scatter(df['MMRAcquisitionAuctionAveragePrice'], df['WarrantyCost'], 
            c=kmeans.labels_, s=20)
plt.scatter(centers[:, 2], centers[:, 1], s=200, marker='*', c='r')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.ylabel('MMRAcquisitionAuctionAveragePrice', fontsize=22)
plt.xlabel('WarrantyCost', fontsize=22)
plt.show()

plt.figure(figsize=(12, 4))
for i in range(0, len(centers)):
    plt.plot(centers[i], marker='o', label='Cluster %s' % i)
plt.tick_params(axis='both', which='major', labelsize=22)
plt.xticks(np.arange(3), ("VehBCost", "WarrantyCost", "MMRAcquisitionAuctionAveragePrice"), fontsize=16)
plt.legend(fontsize=20)
plt.show()

print('SSE %s' % kmeans.inertia_)
print('Silhouette %s' % silhouette_score(X, kmeans.labels_))
# Out:
# SSE 32815.19726468851
# Silhouette 0.28759778031197997

# %%
kmeans = KMeans(n_clusters=9, n_init=10, max_iter=100)
kmeans.fit(X)
np.unique(kmeans.labels_, return_counts=True)
centers = scaler.inverse_transform(kmeans.cluster_centers_)

plt.scatter(df['VehBCost'], df['WarrantyCost'], 
            c=kmeans.labels_, s=20)
plt.scatter(centers[:, 0], centers[:, 1], s=200, marker='*', c='r')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.ylabel('VehBCost', fontsize=22)
plt.xlabel('WarrantyCost', fontsize=22)
plt.show()
plt.scatter(df['VehBCost'], df['MMRAcquisitionAuctionAveragePrice'], 
            c=kmeans.labels_, s=20)
plt.scatter(centers[:, 0], centers[:, 2], s=200, marker='*', c='r')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.ylabel('VehBCost', fontsize=22)
plt.xlabel('MMRAcquisitionAuctionAveragePrice', fontsize=22)
plt.show()
plt.scatter(df['MMRAcquisitionAuctionAveragePrice'], df['WarrantyCost'], 
            c=kmeans.labels_, s=20)
plt.scatter(centers[:, 2], centers[:, 1], s=200, marker='*', c='r')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.ylabel('MMRAcquisitionAuctionAveragePrice', fontsize=22)
plt.xlabel('WarrantyCost', fontsize=22)
plt.show()

plt.figure(figsize=(12, 4))
for i in range(0, len(centers)):
    plt.plot(centers[i], marker='o', label='Cluster %s' % i)
plt.tick_params(axis='both', which='major', labelsize=22)
plt.xticks(np.arange(3), ("VehBCost", "WarrantyCost", "MMRAcquisitionAuctionAveragePrice"), fontsize=16)
plt.legend(fontsize=20)
plt.show()

print('SSE %s' % kmeans.inertia_)
print('Silhouette %s' % silhouette_score(X, kmeans.labels_))
# Out:
# SSE 30143.007795183436
# Silhouette 0.28466092314221736

# %%
kmeans = KMeans(n_clusters=10, n_init=10, max_iter=100)
kmeans.fit(X)
np.unique(kmeans.labels_, return_counts=True)
centers = scaler.inverse_transform(kmeans.cluster_centers_)

plt.scatter(df['VehBCost'], df['WarrantyCost'], 
            c=kmeans.labels_, s=20)
plt.scatter(centers[:, 0], centers[:, 1], s=200, marker='*', c='r')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.ylabel('VehBCost', fontsize=22)
plt.xlabel('WarrantyCost', fontsize=22)
plt.show()
plt.scatter(df['VehBCost'], df['MMRAcquisitionAuctionAveragePrice'], 
            c=kmeans.labels_, s=20)
plt.scatter(centers[:, 0], centers[:, 2], s=200, marker='*', c='r')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.ylabel('VehBCost', fontsize=22)
plt.xlabel('MMRAcquisitionAuctionAveragePrice', fontsize=22)
plt.show()
plt.scatter(df['MMRAcquisitionAuctionAveragePrice'], df['WarrantyCost'], 
            c=kmeans.labels_, s=20)
plt.scatter(centers[:, 2], centers[:, 1], s=200, marker='*', c='r')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.ylabel('MMRAcquisitionAuctionAveragePrice', fontsize=22)
plt.xlabel('WarrantyCost', fontsize=22)
plt.show()

plt.figure(figsize=(12, 4))
for i in range(0, len(centers)):
    plt.plot(centers[i], marker='o', label='Cluster %s' % i)
plt.tick_params(axis='both', which='major', labelsize=22)
plt.xticks(np.arange(3), ("VehBCost", "WarrantyCost", "MMRAcquisitionAuctionAveragePrice"), fontsize=16)
plt.legend(fontsize=20)
plt.show()

print('SSE %s' % kmeans.inertia_)
print('Silhouette %s' % silhouette_score(X, kmeans.labels_))
# Out:
# SSE 28168.737706639466
# Silhouette 0.2679562896544218

# %%
kmeans = KMeans(n_clusters=11, n_init=10, max_iter=100)
kmeans.fit(X)
np.unique(kmeans.labels_, return_counts=True)
centers = scaler.inverse_transform(kmeans.cluster_centers_)

plt.scatter(df['VehBCost'], df['WarrantyCost'], 
            c=kmeans.labels_, s=20)
plt.scatter(centers[:, 0], centers[:, 1], s=200, marker='*', c='r')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.ylabel('VehBCost', fontsize=22)
plt.xlabel('WarrantyCost', fontsize=22)
plt.show()
plt.scatter(df['VehBCost'], df['MMRAcquisitionAuctionAveragePrice'], 
            c=kmeans.labels_, s=20)
plt.scatter(centers[:, 0], centers[:, 2], s=200, marker='*', c='r')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.ylabel('VehBCost', fontsize=22)
plt.xlabel('MMRAcquisitionAuctionAveragePrice', fontsize=22)
plt.show()
plt.scatter(df['MMRAcquisitionAuctionAveragePrice'], df['WarrantyCost'], 
            c=kmeans.labels_, s=20)
plt.scatter(centers[:, 2], centers[:, 1], s=200, marker='*', c='r')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.ylabel('MMRAcquisitionAuctionAveragePrice', fontsize=22)
plt.xlabel('WarrantyCost', fontsize=22)
plt.show()

plt.figure(figsize=(12, 4))
for i in range(0, len(centers)):
    plt.plot(centers[i], marker='o', label='Cluster %s' % i)
plt.tick_params(axis='both', which='major', labelsize=22)
plt.xticks(np.arange(3), ("VehBCost", "WarrantyCost", "MMRAcquisitionAuctionAveragePrice"), fontsize=16)
plt.legend(fontsize=20)
plt.show()

print('SSE %s' % kmeans.inertia_)
print('Silhouette %s' % silhouette_score(X, kmeans.labels_))
# Out:
# SSE 26615.09691874566
# Silhouette 0.25912375924304387

# %%
kmeans = KMeans(n_clusters=12, n_init=10, max_iter=100)
kmeans.fit(X)
np.unique(kmeans.labels_, return_counts=True)
centers = scaler.inverse_transform(kmeans.cluster_centers_)

plt.scatter(df['VehBCost'], df['WarrantyCost'], 
            c=kmeans.labels_, s=20)
plt.scatter(centers[:, 0], centers[:, 1], s=200, marker='*', c='r')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.ylabel('VehBCost', fontsize=22)
plt.xlabel('WarrantyCost', fontsize=22)
plt.show()
plt.scatter(df['VehBCost'], df['MMRAcquisitionAuctionAveragePrice'], 
            c=kmeans.labels_, s=20)
plt.scatter(centers[:, 0], centers[:, 2], s=200, marker='*', c='r')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.ylabel('VehBCost', fontsize=22)
plt.xlabel('MMRAcquisitionAuctionAveragePrice', fontsize=22)
plt.show()
plt.scatter(df['MMRAcquisitionAuctionAveragePrice'], df['WarrantyCost'], 
            c=kmeans.labels_, s=20)
plt.scatter(centers[:, 2], centers[:, 1], s=200, marker='*', c='r')
plt.tick_params(axis='both', which='major', labelsize=22)
plt.ylabel('MMRAcquisitionAuctionAveragePrice', fontsize=22)
plt.xlabel('WarrantyCost', fontsize=22)
plt.show()

plt.figure(figsize=(12, 4))
for i in range(0, len(centers)):
    plt.plot(centers[i], marker='o', label='Cluster %s' % i)
plt.tick_params(axis='both', which='major', labelsize=22)
plt.xticks(np.arange(3), ("VehBCost", "WarrantyCost", "MMRAcquisitionAuctionAveragePrice"), fontsize=16)
plt.legend(fontsize=20)
plt.show()

print('SSE %s' % kmeans.inertia_)
print('Silhouette %s' % silhouette_score(X, kmeans.labels_))
# Out:
# SSE 25126.51268539251
# Silhouette 0.25664389379220076

# %%
kmeans = KMeans(n_clusters=6, n_init=10, max_iter=100)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=100,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
np.unique(kmeans.labels_, return_counts=True)
# Out:
# (array([0, 1, 2]), array([20303, 12364, 21802], dtype=int64))

# %%
plt.scatter(df['VehBCost'], df['WarrantyCost'], 
            c=kmeans.labels_, s=20)
plt.tick_params(axis='both', which='major', labelsize=22)
plt.show()

# %%
plt.scatter(df['VehBCost'], df['MMRAcquisitionAuctionAveragePrice'], 
            c=kmeans.labels_, s=20)
plt.tick_params(axis='both', which='major', labelsize=22)
plt.show()

# %%
plt.scatter(df['MMRAcquisitionAuctionAveragePrice'], df['WarrantyCost'], 
            c=kmeans.labels_, s=20)
plt.tick_params(axis='both', which='major', labelsize=22)
plt.show()

# %%
sse_list = list()
max_k = 50
for k in range(2, max_k + 1):
    kmeans = KMeans(n_clusters=k, n_init=10, max_iter=100)
    kmeans.fit(X)
    
    sse = kmeans.inertia_
    sse_list.append(sse)

# %%
plt.figure(figsize=(20,10))
plt.plot(range(2, len(sse_list) + 2), sse_list)
plt.ylabel('SSE', fontsize=22)
plt.xlabel('K', fontsize=22)
plt.tick_params(axis='both', which='major', labelsize=22)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-41a232d19913> in <module>
#       1 plt.figure(figsize=(20,10))
# ----> 2 plt.plot(range(2, len(sse_list) + 2), sse_list)
#       3 plt.ylabel('SSE', fontsize=22)
#       4 plt.xlabel('K', fontsize=22)
#       5 plt.tick_params(axis='both', which='major', labelsize=22)
#
# NameError: name 'sse_list' is not defined
